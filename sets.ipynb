# %%
thisset = {"apple", "banana", "cherry"}
print(thisset)
# Out:
# {'cherry', 'banana', 'apple'}

# %%
a = {True, 1,2,3,4,5,5, False, 0}
b = {5,6,7,8}

print(a)
# Out:
# {False, True, 2, 3, 4, 5}

# %%
thisset = {"apple", "banana", "cherry"}
print(len(thisset))
print(type(thisset))
# Out:
# 3
# <class 'set'>

# %%
a= set(("apple", "banana", "cherry"))
print(a)
# Out:
# {'cherry', 'banana', 'apple'}

# %%
a = {"apple", "banana", "cherry"}
b = {"grapes", "papaya", "guava"}

a.update(b)
print(a)
# Out:
# {'papaya', 'banana', 'apple', 'grapes', 'cherry', 'guava'}

# %%
thisset = {"tanaji", "more"}
thislist = ["Pune", "Sangola"]

thisset.update(thislist)
print(thisset)
# Out:
# {'tanaji', 'more', 'Pune', 'Sangola'}

# %%
a = {"Tanaji", "More", "tanaji"}
a.clear()
print(a)
# Out:
# set()
