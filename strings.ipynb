# %%
print("It's alright")
# Out:
# It's alright

# %%
a = '''
lorem ipsum dolor sit amet, consectetur adipiscing elit,
sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.
Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat.
'''
print(a)
# Out:
# lorem ipsum dolor sit amet, consectetur adipiscing elit,
# sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.
# Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat.

# %%
a = "Python is fun"
print(a[2])
print(len(a))
# Out:
# t
# 13

# %%
for x in "banana":
    print(x)
# Out:
# b
# a
# n
# a
# n
# a

# %%
txt = "python is awesome and I love python"
if "is" in txt:
    print("Python" not in txt)
# Out:
# True

# %%
a = "Python is fun"
b = "  Python is fun  "
print(a.upper())
print(a.lower())

print(b.strip())

print(a.replace('Python', 'sql'))
print(a)

print(a.split())
# Out:
# PYTHON IS FUN
# python is fun
# Python is fun
# sql is fun
# Python is fun
# ['Python', 'is', 'fun']

# %%
# Out:
# TanajiMore

# %%
age = 26
print(f"My name is Tanaji, My age is {age}")

price = 11
txt = f"The price is {price:.2f} dollars"
print(txt)

a = f"the price is {22 +22} "
print(a)
# Out:
# My name is Tanaji, My age is 26
# The price is 11.00 dollars
# the price is 44

# %%
txt = "we ARE  the so-called Vikings from the north."
print(txt.center(100))
# Out:
#                            we ARE  the so-called Vikings from the north.
