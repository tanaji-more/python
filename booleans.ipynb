# %%
a = 20
b = 0

if a > b: 
    print(" a is greater than b")
else: 
    print(" b is greater than a")
# Out:
#  a is greater than b

# %%
a = ""
b = 0
print(bool(a))
print(bool(b))
# Out:
# False
# False

# %%
class myclass():
    def __len__(self):
        return 0

myobj = myclass()
print(bool(myobj))
# Out:
# False

# %%
def my():
    return True

my()
# Out:
# True
