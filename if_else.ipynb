# %%
a = 20
b = 201

if a>b:
    print("a is greater than b")
elif a>=b:
    print("a is greater than equal")
elif a!=b:
    print("a is not b")
else:
    print("b is greter than a")
# Out:
# a is not b

# %%
score = 100

if score >=90:
    print("Grade A")
elif score >=80:
    print("Grade B")
elif score>=70:
    print("Grade C")
elif score>= 60:
    print("Grade D")
else:
    print("fail")
# Out:
# Grade A
