# %%
a = 20
b = 201

if a>b:
    print("a is greater than b")
elif a>=b:
    print("a is greater than equal")
elif a!=b:
    print("a is not b")
else:
    print("b is greter than a")
# Out:
# a is not b

# %%
score = 100

if score >=90:
    print("Grade A")
elif score >=80:
    print("Grade B")
elif score>=70:
    print("Grade C")
elif score>= 60:
    print("Grade D")
else:
    print("fail")
# Out:
# Grade A

# %%
a = 5
b = 2
if a > b : print("a is greater than b")
# Out:
# a is greater than b

# %%
a = 10
b = 20
print("A") if a > b else print("B")
# Out:
# B

# %%
a = 10
b = 20
bigger = a if a > b else b
short = a if a < b else b
print("Bigger is : ", bigger)
print(short)
# Out:
# Bigger is :  20
# 10

# %%
a = 10
b = 20 
c = 30

if a>b and a>c:
    print("First condition")
else:
    print("Not")
# Out:
# Not

# %%
temp = 25
is_raining = True
is_weekend = False

if (temp > 20 and is_raining) or is_weekend : 
    print("Yeahhh")
else: 
    Print("No")
# Out:
# Yeahhh

# %%
a = 10

if a >= 10:
    print("a is above ten")
    if a > 20:
        print("and also above 20")
    else:
        print("but not above 20")
# Out:
# a is above ten
# but not above 20

# %%
a = 10
b = 20

if b>a:
    pass

# %%
day = 6
match day:
    case 1:
        print("monday")
    case 2:
        print("Tuesday")
    case 3:
        print("Wed")
    case 4:
        print("Thrusday")
    case 5: 
        print("Friday")
    case _:
        print("Done")

a = 10
match a:
    case 1 | 2 | 3 | 4 | 5 :
        print("yes")
    case 6 | 7 : 
        print("alright")
    case _:
        print("No")
# Out:
# Done
# No
