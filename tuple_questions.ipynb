# %%
# 1.Create a tuple of 5 product prices.

product = ("Samsung", "Pixel", "iPhone", "MI")
print(type(product))
# Out:
# <class 'tuple'>

# %%
# 2. Find the maximum value in a tuple.

salary = (1000000, 450000, 33000, 50000, 14000)
max_no = max(salary)
print(max_no)
# Out:
# 1000000

# %%
# 3 Convert a tuple into a list.

mytuple = ("Tanaji", "More", "Pune")

mylist= list(mytuple)
print(mytuple)
print(mylist)
# Out:
# ('Tanaji', 'More', 'Pune')
# ['Tanaji', 'More', 'Pune']

# %%
# 4. Count how many times 500 appears in:

my = (500, 300, 500, 200, 500)

count_500 = my.count(500)
print(count_500)
# Out:
# 3

# %%
# 5. Access the 3rd element of a tuple.

my = (500, 300, 500, 200, 500)

print(my[2])
# Out:
# 500

# %%
# 6. Slice the first 4 elements from a tuple.
my = (500, 300, 500, 200, 500, 600, 700, 800)

print(my[0:4])
# Out:
# (500, 300, 500, 200)

# %%
# 7. Combine two tuples.
my1 = (500, 300, 500, 200)
my2 = (900, 600, 700, 800)

print(my1+ my2)
# Out:
# (500, 300, 500, 200, 900, 600, 700, 800)

# %%
# 8. Check if 700 exists in a tuple.

mytuple = (500, 300, 500, 200, 500, 600, 700, 800)

if mytuple == 500:
    print("yes")

for x in mytuple:
    if x==700:
        print("700 exists")
# Out:
# 700 exists

# %%
# 9. Get index of 300 in a tuple.
mytuple = (500, 400, 500, 300, 500, 600, 700, 800)

print(mytuple.index(300))
# Out:
# 3

# %%
# 10. Convert a list [10, 20, 30] into a tuple.

mylist = [10, 20, 30]
mytuple = tuple(mylist)
print(mytuple)
# Out:
# (10, 20, 30)
