# %%
a= 5
b =10
c = 'Tanaji'
d = 'More'

print(a+ b)
type(a)
print(type(b))
type(a)

a, b, c = "tanaji More", 'pune', 25
print(a)
print(b)    
print(c)
# Out:
# 15
# <class 'int'>
# tanaji More
# pune
# 25

# %%
a = 10

def fun():
    global a
    a = 5
    print("Inside Function:", a)
print("Outside Function:", a)

fun()
print("Outside Function:", a)
# Out:
# Outside Function: 10
# Inside Function: 5
# Outside Function: 5

# %%
import random

print(random.randint(1,10))
# Out:
# 6
