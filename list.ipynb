# %%
mylist = ['Apple', 'Banana', 'Cherry']
list1 = [1, 2, 3]
list2 = [4, 5, 6]
print(mylist)
print(len(mylist))
print(type(list1))

newlist = list(('Apple1', 'Banana1', 'Cherry1'))
print(newlist)
# Out:
# ['Apple', 'Banana', 'Cherry']
# 3
# <class 'list'>
# ['Apple1', 'Banana1', 'Cherry1']

# %%
a = ['apple', 'banana', 'cherry', 'anar', 'graphes']
print(a[1:4])
print(a[:4])
print(a[2:])
print(a[-4:-1])
print(a[-4:])
# Out:
# ['banana', 'cherry', 'anar']
# ['apple', 'banana', 'cherry', 'anar']
# ['cherry', 'anar', 'graphes']
# ['banana', 'cherry', 'anar']
# ['banana', 'cherry', 'anar', 'graphes']

# %%
a = ['apple', 'banana', 'cherry', 'anar', 'graphes']

if "Apple" in a:
    print("Yes, 'apple' is in the fruits list")
else:   
    print("No, 'apple' is not in the fruits list")
# Out:
# No, 'apple' is not in the fruits list

# %%
a = ['apple', 'banana', 'cherry', 'anar', 'graphes']
a[1] = "blackcurrant"
print(a)
# Out:
# ['apple', 'blackcurrant', 'cherry', 'anar', 'graphes']

# %%
a = ['apple', 'banana', 'cherry', 'anar', 'graphes', 'kiwi', 'mango']
a[1:5] = ["blackcurrant", "watermelon"]
print(a)

thislist = ["apple", "banana", "cherry"]
thislist[1:3] = ["watermelon"]
print(thislist)
# Out:
# ['apple', 'blackcurrant', 'watermelon', 'kiwi', 'mango']
# ['apple', 'watermelon']

# %%
a = ['apple', 'banana', 'cherry', 'anar', 'graphes', 'kiwi', 'mango']

a.insert(2, "orange")
print(a)
# Out:
# ['apple', 'banana', 'orange', 'cherry', 'anar', 'graphes', 'kiwi', 'mango']

# %%
thislist = ["apple", "banana", "cherry"]
thislist.append("orange")
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %%
thislist = ["apple", "banana", "cherry"]
tropical = ["mango", "pineapple", "papaya"]
thislist.extend(tropical)
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'pineapple', 'papaya']

# %%
thislist = ["apple", "banana", "cherry"]
thistuple = ("kiwi", "orange")
thislist.extend(thistuple)
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'kiwi', 'orange']

# %%
a = ['apple', 'banana', 'banana', 'cherry', 'anar', 'graphes', 'kiwi', 'mango']
print(a)

a.pop()
print(a)
del a[0]
print(a)

del a
# Out:
# ['apple', 'banana', 'banana', 'cherry', 'anar', 'graphes', 'kiwi', 'mango']
# ['apple', 'banana', 'banana', 'cherry', 'anar', 'graphes', 'kiwi']
# ['banana', 'banana', 'cherry', 'anar', 'graphes', 'kiwi']

# %%
thislist = ["apple", "banana", "cherry"]
thislist.clear()
print(thislist)
# Out:
# []

# %%
thislist = ["apple", "banana", "cherry"]

for x in thislist:
    print(x)
# Out:
# apple
# banana
# cherry

# %%
thislist = ["apple", "banana", "cherry"]

for i in range(len(thislist)):
    print(thislist[i])
# Out:
# apple
# banana
# cherry

# %%
thislist = ["apple", "banana", "cherry"]
[print(x) for x in thislist]
# Out:
# apple
# banana
# cherry
# [None, None, None]

# %%
fruits = ["apple", "banana", "cherry", "kiwi", "mango"] 
newlist = []

for x in fruits:
    if "m" in x:
        newlist.append(x)

print(newlist)
# Out:
# ['mango']

# %%
# With list comprehension

fruits = ["apple", "banana", "cherry", "kiwi", "mango"]
newlist = [x for x in fruits if 'a' in x]
print(newlist)
# Out:
# ['apple', 'banana', 'mango']

# %%
a = ['apple', 'banana', 'cherry', 'anar', 'graphes', 'kiwi', 'mango']

b = [i for i in a if 'a' in i]
print(b)
# Out:
# ['apple', 'banana', 'anar', 'graphes', 'mango']

# %%
print(b)
# Out:
# ['apple', 'banana', 'anar', 'graphes', 'mango']

# %%
newlist = [x for x in range(10) if x<5]
print(newlist)
# Out:
# [0, 1, 2, 3, 4]

# %%
a = ['apple', 'banana', 'cherry', 'anar', 'graphes', 'kiwi', 'mango']
a.sort(reverse=True)
print(a)
# Out:
# ['mango', 'kiwi', 'graphes', 'cherry', 'banana', 'apple', 'anar']

# %%
thislist = ["banana", "Orange", "Kiwi", "cherry"]
thislist.sort(key = str.lower)
print(thislist)
# Out:
# ['banana', 'cherry', 'Kiwi', 'Orange']

# %%
thislist = ["banana", "Orange", "Kiwi", "cherry"]

thislist.sort(reverse=True)
print(thislist)
# Out:
# ['cherry', 'banana', 'Orange', 'Kiwi']
