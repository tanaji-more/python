# %%
fruits= ["Apple", "Banna", "Cherry"]

for i in fruits:
    print(i)
# Out:
# Apple
# Banna
# Cherry

# %%
fruits= ["Apple", "Banana", "Cherry"]

for i in fruits:
    if i == "Banana":
        continue
    print(i)
# Out:
# Apple
# Cherry
