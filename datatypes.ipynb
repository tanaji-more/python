# %%
mylist = ['tanaji', 'more', 'sidhu']
print(mylist)
# Out:
# ['tanaji', 'more', 'sidhu']

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "mango"]
thislist[1:3] = ["blackcurrant", "watermelon"]
print(thislist)
# Out:
# ['apple', 'blackcurrant', 'watermelon', 'orange', 'kiwi', 'mango']

# %%
thislist = ["apple", "banana", "cherry"]
thislist[1:3] = ["watermelon"]
print(thislist)
# Out:
# ['apple', 'watermelon']

# %%
thislist = ['tanaji', 'more', 'sidhu']
thislist.insert(1, 'mahadev')
print(thislist)
# Out:
# ['tanaji', 'mahadev', 'more', 'sidhu']

# %%
thislist = ["apple", "banana", "cherry"]
thislist.append("orange")
print(thislist)
# Out:
# ['apple', 'banana', 'orange']
