# %%
# this is normal
try:
    num = int(input("Enter the number"))
    result = 100 / num
    print(result)
except:
    print("Something Went wrong")
# Out:
# 11.11111111111111

# %%
# Specific exceptions

try:
    num= int(input("Enter the number : "))
    result= 100/ num 
    preint("Result: ", result)
except ZeroDivisionError:
    print("Cannot devide by zero")

except ValueError:
    print("Please enter the a valid number")
# Out:
# Please enter the a valid number
