# %%
""" Given a list of daily sales: sales = [1200, 1500, 1100, 1800, 1700, 1600]
➝ Find total revenue."""

sales = [1200, 1500, 1100, 1800, 1700, 1600]

total_revenue= sales.sum()
print(total_revenue)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 6
#       1 """ Given a list of daily sales: sales = [1200, 1500, 1100, 1800, 1700, 1600]
#       2 ➝ Find total revenue."""
#       4 sales = [1200, 1500, 1100, 1800, 1700, 1600]
# ----> 6 total_revenue= sales.sum()
#       7 print(total_revenue)
#
# AttributeError: 'list' object has no attribute 'sum'
