# %%
# Out:
# {'Name': 'Tanaji', 'Age': '20', 'Year': '2024'}
# 3

# %%
a = {
    "name":"Tanaji",
    "age":20,
    "Role":["Data Engineer","Web Developer"],
    "salary":70000

}

print(a)
print(type(a))
# Out:
# {'name': 'Tanaji', 'age': 20, 'Role': ['Data Engineer', 'Web Developer'], 'salary': 70000}
# <class 'dict'>

# %%
a = dict(name="Tanaji", age=20, role=["Data Engineer", "Web Developer"], salary=70000)

x = a["role"]
y = print(x) # or
y1 = a.get("salary")
print(y1)
# Out:
# ['Data Engineer', 'Web Developer']
# 70000

# %%
car = {
"brand": "Ford",
"model": "Mustang",
"year": 1964
}

x = car.keys()
z = car.values()
print(z)
print(x)

car["color"] = "red"
print(x)


a = car.items()
print(a)

a = car.items()
print(a)

car["type"] = "SUV"
print(a)
# Out:
# dict_values(['Ford', 'Mustang', 1964])
# dict_keys(['brand', 'model', 'year'])
# dict_keys(['brand', 'model', 'year', 'color'])
# dict_items([('brand', 'Ford'), ('model', 'Mustang'), ('year', 1964), ('color', 'red')])
# dict_items([('brand', 'Ford'), ('model', 'Mustang'), ('year', 1964), ('color', 'red')])
# dict_items([('brand', 'Ford'), ('model', 'Mustang'), ('year', 1964), ('color', 'red'), ('type', 'SUV')])

# %%
dic1 = {
    "name": "Tanaji",
    "age":22,
    "city":"Pune"

}

if "name" in dic1:
    print("Yes, 'name' is one of the keys in the dic1 dictionary")  


dic1.update({"name":"More"})
print(dic1)
# Out:
# Yes, 'name' is one of the keys in the dic1 dictionary
# {'name': 'More', 'age': 22, 'city': 'Pune'}

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

thisdict.pop("model")
print(thisdict)
# Out:
# {'brand': 'Ford', 'year': 1964}

# %%
thisdict= {
    "brand": "Ford",
    "model": "Mustang",
    "year": 1964
}

thisdict.popitem()
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang'}

# %%
thisdict= {
    "brand": "Ford",
    "model": "Mustang",
    "year": 1964
}

for x in thisdict.keys():
    print(x)
# Out:
# brand
# model
# year

# %%
thisdict= {
    "brand": "Ford",
    "model": "Mustang",
    "year": 1964
}

mydict = thisdict.copy()
print(mydict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
myfamily={

    "family1": {
        "name":"Tanaji",
        "age":20,
        "city":"Pune"
        
    },

    "family2":{
        "name":"Satyaji",
        "age": 50,
        "city":"mumbai"
    },

    "family3":{
        "name":"Satyabhama",
        "age": 45,
        "city":"mumbai"
    }
}

print(myfamily)
print(myfamily["family1"]["name"])
# Out:
# {'family1': {'name': 'Tanaji', 'age': 20, 'city': 'Pune'}, 'family2': {'name': 'Satyaji', 'age': 50, 'city': 'mumbai'}, 'family3': {'name': 'Satyabhama', 'age': 45, 'city': 'mumbai'}}
# Tanaji
